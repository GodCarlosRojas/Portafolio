# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %%
model = Sequential()

# %%
model.add(Flatten(input_shape=(28, 28)))

# %%
model.add(Dense(128, activation='relu'))

# %%
model.add(Dense(64, activation='relu'))

# %%
model.add(Dense(10, activation='softmax'))
# por la salida

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 938/938 [==============================] - 5s 5ms/step - loss: 0.2776 - accuracy: 0.9202 - val_loss: 0.1410 - val_accuracy: 0.9557
# Epoch 2/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1126 - accuracy: 0.9666 - val_loss: 0.1025 - val_accuracy: 0.9679
# Epoch 3/10
# 938/938 [==============================] - 5s 6ms/step - loss: 0.0780 - accuracy: 0.9761 - val_loss: 0.0899 - val_accuracy: 0.9716
# Epoch 4/10
# 938/938 [==============================] - 5s 6ms/step - loss: 0.0580 - accuracy: 0.9813 - val_loss: 0.0903 - val_accuracy: 0.9731
# Epoch 5/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0468 - accuracy: 0.9849 - val_loss: 0.0857 - val_accuracy: 0.9737
# Epoch 6/10
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0362 - accuracy: 0.9882 - val_loss: 0.0809 - val_accuracy: 0.9759
# Epoch 7/10
# ...

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Exactitud en los datos de prueba: {test_acc}')
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0814 - accuracy: 0.9768
# Exactitud en los datos de prueba: 0.9768000245094299

# %%
digit_names = {
    0: 'Cero',
    1: 'Uno',
    2: 'Dos',
    3: 'Tres',
    4: 'Cuatro',
    5: 'Cinco',
    6: 'Seis',
    7: 'Siete',
    8: 'Ocho',
    9: 'Nueve'
}
# :3

# %%
def mostrar_imagen(image, label):
    plt.figure()
    plt.imshow(image, cmap='gray')
    plt.title(f'Dígito: {digit_names[label]}')
    plt.axis('off')
    plt.show()

# %%
for i in range(10):
    index = next((index for index, value in enumerate(y_train) if value == i), None)
    if index is not None:
        mostrar_imagen(x_train[index], y_train[index])
